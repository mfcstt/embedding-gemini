# %% [markdown]
# <a href="https://colab.research.google.com/github/mfcstt/embedding-gemini/blob/main/embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instalando o SDK do Google

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 1.2 MB/s eta 0:00:00

# %%
import numpy as np
import pandas as pd
import google.generativeai as genai
from google.colab import userdata

GOOGLE_API_KEY=('AIzaSyA0mD8WAy1Fx84x4WAoHbmRChAKdAYhCjs')
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Listar os modelos disponíveis

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %% [markdown]
# Trabalhando com embedding

# %%
text = "Olá"
result = genai.embed_content(model="models/embedding-001", content=text)
embedding = result['embedding']
print(embedding)
# Out:
# [0.008645346, -0.016980717, -0.0085139945, 0.009878001, 0.044365767, -0.0019685389, -0.0009623616, -0.0047898768, 0.012247335, 0.012026606, 0.024517149, 0.028255783, -0.003410204, -0.061565474, 0.004716482, -0.0037836356, 0.011095671, 0.009222746, -0.029866563, -0.042922262, 0.03828968, 0.01817658, -0.037122335, -0.0069611925, 0.02088841, -0.008916729, 0.00388277, -0.04796051, -0.0044384007, 0.06290224, -0.03219062, 0.028923195, -0.0546672, 0.028031752, 0.01400026, -0.041399803, 0.017214108, 0.056057002, 0.0009515392, 0.015584149, 0.017807689, -0.07053892, -0.011525921, -0.033663813, 0.03376112, -0.03498179, 0.00012872883, 0.01354553, -0.0028834941, -0.064458214, 0.05395861, 0.011263261, 0.031246224, 0.0014113381, -0.024068868, -0.03242663, 0.06361604, 0.019462816, -0.05619286, 0.011152544, -0.022256363, 0.037176397, 0.048917674, 0.06134715, 0.0098138405, -0.04028734, -0.041014712, 0.01577806, 0.038432416, -0.00129989, -0.0032752713, -0.060223226, 0.026976695, -0.022825552, -0.03609388, -0.042841535, -0.00559325, 0.06441695, 0.02576555, -0.009142427, -0.017857132, -0.06435687, -0.008077656, -0.02214027, -0.09566939, 0.052729007, -0.035732295, -0.0004276363, -0.008394382, 0.048114393, -0.0030342916, -0.029297646, 0.04333388, -0.054266263, -0.054059725, 0.057184577, -0.04553105, -0.012696515, -0.012118018, -0.049594812, 0.028427366, -0.014142576, -0.051349074, -0.009750772, -0.015112742, 0.057255197, -0.029206274, 0.025656702, -0.003042806, 0.05466044, -0.03104386, 0.028451888, -0.01656863, -0.011351159, 0.03521365, -0.023462744, 0.0081942985, 0.11762708, 0.042657092, 0.051712643, -0.010283964, -0.007637243, 0.034484, -0.016784761, 0.020005098, 0.03290189, 0.016705217, 0.03329187, 0.05455589, 0.013218045, -0.012574192, -0.030380948, 0.027800186, 0.042947497, 0.030751651, 0.012190432, 0.085113734, -0.004294229, 0.043709394, 0.039220408, -0.0059
609919, -0.01987017, 0.002294952, -0.010430027, -0.015530529, -0.019767161, -0.008867147, -0.0068671564, 0.0057947743, 0.04330911, 0.016776504, -0.007212231, -0.04273343, -0.039162707, -0.010437393, -0.020961389, -0.0030755114, -0.030543268, -0.036151767, 0.033071604, -0.026332987, -0.052153178, 0.024657838, 0.034173757, 0.014873449, -0.026967471, 0.022019275, -0.034127038, -0.06492789, 0.026274493, -0.0035025543, -0.018625837, -0.030615857, -0.007239309, -0.02800939, 0.028896132, 0.041577745, 0.016184606, 0.008275006, -0.030568445, 0.0142051475, 0.07795622, 0.047304224, 0.01270549, 0.0013281942, 0.03114561, 0.0926986, -0.015973164, -0.041795995, 0.0610494, -0.030569592, 0.01735479, 0.022733154, 0.03387262, 0.049996145, -0.013368156, 0.0038711755, 0.015858244, -0.019469677, -0.041606415, -0.020492384, -0.00028909434, -0.04738342, -0.013358463, -0.0060154377, 0.05825934, -0.05827397, 0.08012868, 0.031748675, -0.072179005, 0.042532366, 0.069887936, 0.052565, 0.004562372, 0.06118634, -0.00805996, 0.030369757, 0.020066045, -0.006681057, 0.043854587, -0.016400404, 0.041174874, 0.05162581, 0.04198593, -0.054925498, 0.03866314, -0.01885172, 0.06644836, -0.016790703, 0.028624916, -0.006876024, -0.05641254, -0.03073679, 0.047078535, -0.064925045, 0.021379309, -0.07598943, -0.037462603, 0.0486096, -0.018470591, 0.06826002, -0.019153195, 0.0022164097, 0.0043610907, -0.008804555, -0.04410768, 0.00706547, 0.03562648, -0.047724597, 0.016996238, 0.008586738, -0.03246806, 0.06399957, 0.049599793, -0.013782887, 0.005683452, -0.010373172, 0.04592761, 0.04826426, -0.047988046, 0.03479883, 0.04997684, 0.0013625838, -0.048479013, -0.029808126, 0.0061359955, -0.036821015, -0.039377194, 0.042686388, -0.039435543, -0.08356463, 0.018111778, -0.0028617536, 0.02892799, -0.030500857, -0.01705199, -0.026729802, 0.01813781, 0.036547553, - ...

# %% [markdown]
# Listagem de documentos que serão buscados

# %%
DOCUMENT2 = {
    "Título": "Touchscreen",
    "Conteúdo": "O seu Googlecar tem uma grande tela sensível ao toque que fornece acesso a uma variedade de recursos, incluindo navegação, entretenimento e controle climático. Para usar a tela sensível ao toque, basta tocar no ícone desejado.  Por exemplo, você pode tocar no ícone \"Navigation\" (Navegação) para obter direções para o seu destino ou tocar no ícone \"Music\" (Música) para reproduzir suas músicas favoritas."}

DOCUMENT3 = {
    "Título": "Mudança de marchas",
    "Conteúdo": "Seu Googlecar tem uma transmissão automática. Para trocar as marchas, basta mover a alavanca de câmbio para a posição desejada.  Park (Estacionar): Essa posição é usada quando você está estacionado. As rodas são travadas e o carro não pode se mover. Marcha à ré: Essa posição é usada para dar ré. Neutro: Essa posição é usada quando você está parado em um semáforo ou no trânsito. O carro não está em marcha e não se moverá a menos que você pressione o pedal do acelerador. Drive (Dirigir): Essa posição é usada para dirigir para frente. Low: essa posição é usada para dirigir na neve ou em outras condições escorregadias."}

documents = [DOCUMENT2, DOCUMENT3]

# %%
df = pd.DataFrame(documents)
df.columns = ["Titulo", "Conteudo"]
df
# Out:
#                Titulo                                           Conteudo
# 0         Touchscreen  O seu Googlecar tem uma grande tela sensível a...
# 1  Mudança de marchas  Seu Googlecar tem uma transmissão automática. ...

# %% [markdown]
# Criando o modelo

# %%
model = "models/embedding-001"

# %%
def embed_fn(title, text):
  return genai.embed_content(model=model, content=text, title=title, task_type="RETRIEVAL_DOCUMENT")['embedding']

# %%
df['Embeddings'] = df.apply(lambda row: embed_fn(row["Titulo"], row["Conteudo"]), axis=1)
df
# Out:
#                Titulo                                           Conteudo  \
# 0         Touchscreen  O seu Googlecar tem uma grande tela sensível a...
# 1  Mudança de marchas  Seu Googlecar tem uma transmissão automática. ...
#
#                                           Embeddings
# 0  [0.015715627, -0.040427547, 0.011117627, 0.002...
# 1  [-0.009390755, -0.022475218, -0.0024638234, 0....

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model, content=consulta, task_type="RETRIEVAL_QUERY")['embedding']

  produtos_escalares = np.dot(np.stack(df['Embeddings']), embedding_da_consulta)
  index = np.argmax(produtos_escalares)

  return df.iloc[index]['Conteudo']

# %%
consulta = "Como faço para trocar marchas em um carro do Google?"

response = gerar_e_buscar_consulta(consulta, df, model)
print(response)
# Out:
# Seu Googlecar tem uma transmissão automática. Para trocar as marchas, basta mover a alavanca de câmbio para a posição desejada.  Park (Estacionar): Essa posição é usada quando você está estacionado. As rodas são travadas e o carro não pode se mover. Marcha à ré: Essa posição é usada para dar ré. Neutro: Essa posição é usada quando você está parado em um semáforo ou no trânsito. O carro não está em marcha e não se moverá a menos que você pressione o pedal do acelerador. Drive (Dirigir): Essa posição é usada para dirigir para frente. Low: essa posição é usada para dirigir na neve ou em outras condições escorregadias.

# %% [markdown]
# Ajustando a resposta de uma forma descontraída

# %%
prompt = f"Reescreva esse texto de uma forma mais descontraída, sem adicionar informações que não façam parte do texto: {consulta}"

generation_config = {
    'candidate_count': 1,
    'temperature': 0.5
}

model_2 = genai.GenerativeModel(model_name="gemini-1.0-pro", generation_config=generation_config)
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# Ei, galera! Querem saber como trocar marchas no carro do Google? É moleza!
#
# Não tem volante, nem pedais, então é só relaxar e curtir o passeio. O carro faz tudo sozinho, tipo um supercomputador sobre rodas.
#
# Então, pode esquecer a embreagem, o câmbio e todo aquele lance de "primeira, segunda, terceira". É só entrar, apertar o botão e curtir a viagem!
